# %% [markdown]
# # Chapter 01 Python Introduction

# %% [markdown]
# ## Hello World

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# ## Class

# %% [markdown]
# ### Define a Class

# %%
class Man:
    def __init__(self, name):
        self.name = name
        print("Initialized!")
    def hello(self):
        print("Hello " + self.name + "!")
    def goodbye(self):
        print("Good-bye " + self.name + "!")

# %% [markdown]
# ### Call the Class

# %%
m = Man("David")
m.hello()
m.goodbye()
# Out:
# Initialized!
# Hello David!
# Good-bye David!
